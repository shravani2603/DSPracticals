# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_csv("adult.csv", header=None)
df
# Out:
#        0                  1       2            3   4                    5
# 0      39          State-gov   77516    Bachelors  13        Never-married  \
# 1      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2      38            Private  215646      HS-grad   9             Divorced
# 3      53            Private  234721         11th   7   Married-civ-spouse
# 4      28            Private  338409    Bachelors  13   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32556  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32557  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32558  58            Private  151910      HS-grad   9              Widowed
# 32559  22            Private  201490      HS-grad   9        Never-married
# 32560  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
# ...

# %%
col=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain','capital-loss','hours-per-week','native-country','target']
df.columns=col
df
# Out:
#        age          workclass  fnlwgt    education  education-num
# 0       39          State-gov   77516    Bachelors             13  \
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race
# 0            Never-married        Adm-clerical   Not-in-family   White  \
# ...

# %% [markdown]
# # 1.Create data subsets for different Country, Sex, race.

# %%
df["native-country"].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df["sex"].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
df["race"].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
df_united=df[df["native-country"]==" United-States"]
df_united.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   39          State-gov   77516   Bachelors             13  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 5   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex
# 0        Never-married        Adm-clerical   Not-in-family   White     Male  \
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 5   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df_cuba= df[df["native-country"]==" Cuba"]
df_cuba.head()
# Out:
#       age          workclass  fnlwgt   education  education-num
# 4      28            Private  338409   Bachelors             13  \
# 81     52            Private  276515   Bachelors             13
# 638    47       Self-emp-inc  248145     5th-6th              3
# 701    31            Private  243605   Bachelors             13
# 1237   41   Self-emp-not-inc  209344     HS-grad              9
#
#            marital-status         occupation     relationship    race
# 4      Married-civ-spouse     Prof-specialty             Wife   Black  \
# 81     Married-civ-spouse      Other-service          Husband   White
# 638    Married-civ-spouse   Transport-moving          Husband   White
# 701               Widowed              Sales        Unmarried   White
# 1237   Married-civ-spouse              Sales   Other-relative   White
#
#           sex  capital-gain  capital-loss  hours-per-week native-country
# 4      Female             0             0              40           Cuba  \
# ...

# %%
df_male=df[df["sex"]==" Male"]
df_male.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   39          State-gov   77516   Bachelors             13  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 7   52   Self-emp-not-inc  209642     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex
# 0        Never-married        Adm-clerical   Not-in-family   White   Male  \
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
# 7   Married-civ-spouse     Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df_female=df[df["sex"]==" Female"]
df_female
# Out:
#        age      workclass  fnlwgt      education  education-num
# 4       28        Private  338409      Bachelors             13  \
# 5       37        Private  284582        Masters             14
# 6       49        Private  160187            9th              5
# 8       31        Private   45781        Masters             14
# 12      23        Private  122272      Bachelors             13
# ...    ...            ...     ...            ...            ...
# 32546   37        Private  198216     Assoc-acdm             12
# 32549   43      State-gov  255835   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32558   58        Private  151910        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#                marital-status        occupation     relationship    race
# 4          Married-civ-spouse    Prof-specialty             Wife   Black  \
# ...

# %%
df_white= df[df["race"]==" White"]
df_white.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   39          State-gov   77516   Bachelors             13  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 5   37            Private  284582     Masters             14
# 7   52   Self-emp-not-inc  209642     HS-grad              9
#
#         marital-status          occupation    relationship    race      sex
# 0        Never-married        Adm-clerical   Not-in-family   White     Male  \
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 5   Married-civ-spouse     Exec-managerial            Wife   White   Female
# 7   Married-civ-spouse     Exec-managerial         Husband   White     Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df_black= df[df["race"]==" Black"]
df_black.head()
# Out:
#     age workclass  fnlwgt      education  education-num
# 3    53   Private  234721           11th              7  \
# 4    28   Private  338409      Bachelors             13
# 6    49   Private  160187            9th              5
# 10   37   Private  280464   Some-college             10
# 13   32   Private  205019     Assoc-acdm             12
#
#             marital-status          occupation    relationship    race
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black  \
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# 6    Married-spouse-absent       Other-service   Not-in-family   Black
# 10      Married-civ-spouse     Exec-managerial         Husband   Black
# 13           Never-married               Sales   Not-in-family   Black
#
#         sex  capital-gain  capital-loss  hours-per-week  native-country
# 3      Male             0             0              40   United-States  \
# ...

# %%
df_asian= df[df["race"]==" Asian-Pac-Islander"]
df_asian.head()
# Out:
#      age   workclass  fnlwgt      education  education-num
# 11    30   State-gov  141297      Bachelors             13  \
# 14    40     Private  121772      Assoc-voc             11
# 27    54           ?  180211   Some-college             10
# 93    30     Private  117747        HS-grad              9
# 139   49     Private   81973   Some-college             10
#
#           marital-status       occupation relationship                 race
# 11    Married-civ-spouse   Prof-specialty      Husband   Asian-Pac-Islander  \
# 14    Married-civ-spouse     Craft-repair      Husband   Asian-Pac-Islander
# 27    Married-civ-spouse                ?      Husband   Asian-Pac-Islander
# 93    Married-civ-spouse            Sales         Wife   Asian-Pac-Islander
# 139   Married-civ-spouse     Craft-repair      Husband   Asian-Pac-Islander
#
#          sex  capital-gain  capital-loss  hours-per-week  native-country
# 11      Male             0             0              40           India  \
# ...

# %%
df_amer=df[df["race"]==" Amer-Indian-Eskimo"]
df_amer.head()
# Out:
#      age workclass  fnlwgt      education  education-num       marital-status
# 15    34   Private  245487        7th-8th              4   Married-civ-spouse  \
# 212   35   Private  153790   Some-college             10        Never-married
# 226   60         ?   24215           10th              6             Divorced
# 447   51   Private   56915        HS-grad              9   Married-civ-spouse
# 516   25   Private  267044   Some-college             10        Never-married
#
#             occupation    relationship                 race      sex
# 15    Transport-moving         Husband   Amer-Indian-Eskimo     Male  \
# 212              Sales   Not-in-family   Amer-Indian-Eskimo   Female
# 226                  ?   Not-in-family   Amer-Indian-Eskimo   Female
# 447       Craft-repair         Husband   Amer-Indian-Eskimo     Male
# 516       Adm-clerical   Not-in-family   Amer-Indian-Eskimo   Female
#
#      capital-gain  capital-loss  hours-per-week  native-country  target
# ...

# %%
df_other=df[df["race"]==" Other"]
df_other.head()
# Out:
#      age workclass  fnlwgt      education  education-num       marital-status
# 50    25   Private   32275   Some-college             10   Married-civ-spouse  \
# 233   33   Private  110978   Some-college             10             Divorced
# 356   65   Private  161400           11th              7              Widowed
# 404   28   Private  166481        7th-8th              4   Married-civ-spouse
# 530   44   Private  109339           11th              7             Divorced
#
#              occupation     relationship    race      sex  capital-gain
# 50      Exec-managerial             Wife   Other   Female             0  \
# 233        Craft-repair   Other-relative   Other   Female             0
# 356       Other-service        Unmarried   Other     Male             0
# 404   Handlers-cleaners          Husband   Other     Male             0
# 530   Machine-op-inspct        Unmarried   Other   Female             0
#
#      capital-loss  hours-per-week  native-country  target
# ...

# %% [markdown]
# # 2.Merge two subsets

# %%
df_male_cuba= pd.concat([df_male, df_cuba])
df_male_cuba.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   39          State-gov   77516   Bachelors             13  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 7   52   Self-emp-not-inc  209642     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex
# 0        Never-married        Adm-clerical   Not-in-family   White   Male  \
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
# 7   Married-civ-spouse     Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
print("shape of male subset: ",df_male.shape)
print("shape of cuba subset: ", df_cuba.shape)
print("shape of male_cuba subset: ",df_male_cuba.shape)
# Out:
# shape of male subset:  (21790, 15)
# shape of cuba subset:  (95, 15)
# shape of male_cuba subset:  (21885, 15)

# %%
df_united_female_black= pd.concat([df_united, df_female, df_black])
df_united_female_black.head()
# Out:
#    age          workclass  fnlwgt   education  education-num
# 0   39          State-gov   77516   Bachelors             13  \
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 5   37            Private  284582     Masters             14
#
#         marital-status          occupation    relationship    race      sex
# 0        Never-married        Adm-clerical   Not-in-family   White     Male  \
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 5   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
print("shape of united subset: ", df_united.shape)
print("shape of female subset: ", df_female.shape)
print("shape of black subset: ", df_black.shape)
print("shape of merged subset: ", df_united_female_black.shape)
# Out:
# shape of united subset:  (29170, 15)
# shape of female subset:  (10771, 15)
# shape of black subset:  (3124, 15)
# shape of merged subset:  (43065, 15)

# %% [markdown]
# # 3. Sort Data according to age

# %%
df_sort= df.sort_values(by=["age"])
df_sort
# Out:
#        age          workclass  fnlwgt      education  education-num
# 12318   17            Private  127366           11th              7  \
# 6312    17            Private  132755           11th              7
# 30927   17            Private  108470           11th              7
# 12787   17          Local-gov  308901           11th              7
# 25755   17                  ?   47407           11th              7
# ...    ...                ...     ...            ...            ...
# 24043   90   Self-emp-not-inc   82628        HS-grad              9
# 32277   90            Private  313749        HS-grad              9
# 5104    90            Private   52386   Some-college             10
# 8963    90                  ?   77053        HS-grad              9
# 10210   90   Self-emp-not-inc  282095   Some-college             10
#
#             marital-status        occupation    relationship
# 12318        Never-married             Sales       Own-child  \
# ...

# %%
df_transpose= df.transpose()
df_transpose
# Out:
#                          0                    1                   2
# age                         39                   50                  38  \
# workclass            State-gov     Self-emp-not-inc             Private
# fnlwgt                   77516                83311              215646
# education            Bachelors            Bachelors             HS-grad
# education-num               13                   13                   9
# marital-status   Never-married   Married-civ-spouse            Divorced
# occupation        Adm-clerical      Exec-managerial   Handlers-cleaners
# relationship     Not-in-family              Husband       Not-in-family
# race                     White                White               White
# sex                       Male                 Male                Male
# capital-gain              2174                    0                   0
# capital-loss                 0                    0                   0
# ...

# %% [markdown]
# # 5.Melting Data to long Format

# %%
df_melted= pd.melt(df, id_vars=["workclass", "education"], var_name="Metric", value_name="value")
df_melted
# Out:
#                 workclass    education  Metric   value
# 0               State-gov    Bachelors     age      39
# 1        Self-emp-not-inc    Bachelors     age      50
# 2                 Private      HS-grad     age      38
# 3                 Private         11th     age      53
# 4                 Private    Bachelors     age      28
# ...                   ...          ...     ...     ...
# 423288            Private   Assoc-acdm  target   <=50K
# 423289            Private      HS-grad  target    >50K
# 423290            Private      HS-grad  target   <=50K
# 423291            Private      HS-grad  target   <=50K
# 423292       Self-emp-inc      HS-grad  target    >50K
#
# [423293 rows x 4 columns]

# %% [markdown]
# # 6.Casting data to wide format

# %%
df_casted= pd.pivot_table(df, index=["workclass", "occupation"], values=["hours-per-week"])
df_casted


#This code creates a pivot table from the DataFrame df, where:

#The rows of the pivot table are indexed by unique combinations of the workclass an occupation columns from the original DataFrame.
#The values in the pivot table are obtained from the hours-per-week column of the original DataFrame.
#By default, the pivot table will calculate the mean (average) for 'hours-per-week' for each combination of 'workclass' and 'occupation'.
#So, the resulting pivot table provides a summary of the average number of hours per week worked for each combination of 'workclass' and 'occupation' in the original DataFrame.
# Out:
#                                  hours-per-week
# workclass    occupation
#  ?            ?                       31.919390
#  Federal-gov  Adm-clerical            40.154574
#               Armed-Forces            40.666667
#               Craft-repair            40.781250
#               Exec-managerial         42.572222
# ...                                         ...
#  Without-pay  Farming-fishing         36.666667
#               Handlers-cleaners       40.000000
#               Machine-op-inspct       25.000000
#               Other-service           55.000000
#               Transport-moving        20.000000
#
# [83 rows x 1 columns]

# %%
df["workclass"].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df["occupation"].unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df_casted.head(50)
# Out:
#                                   hours-per-week
# workclass     occupation
#  ?             ?                       31.919390
#  Federal-gov   Adm-clerical            40.154574
#                Armed-Forces            40.666667
#                Craft-repair            40.781250
#                Exec-managerial         42.572222
#                Farming-fishing         40.000000
#                Handlers-cleaners       39.260870
#                Machine-op-inspct       39.285714
#                Other-service           37.514286
#                Prof-specialty          43.331429
#                Protective-serv         49.821429
#                Sales                   41.857143
#                Tech-support            38.132353
#                Transport-moving        44.520000
#  Local-gov     Adm-clerical            36.462898
#                Craft-repair            41.089041
#                Exec-managerial         43.317757
#                Farming-fishing         39.482759
# ...
